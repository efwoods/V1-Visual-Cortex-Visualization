# %% [markdown]
# # Expanding to generate images on a real image dataset

# %%
# Imports 
import os
import torch
import torch.nn as nn
import torch.optim as optim
from torch.utils.data import Dataset, DataLoader
from torchvision import transforms, datasets, utils
from torch.utils.data import Dataset, DataLoader
from PIL import Image
from glob import glob
from tqdm import tqdm

# %%
# Configuration
DATA_DIR = "/home/linux-pc/gh/V1-Visual-Cortex-Visualization/data/crcns-pvc1/crcns-ringach-data/movie_frames/movie000_000.images/"
BATCH_SIZE = 128
IMAGE_SIZE = 64
EPOCHS = 100
LATENT_DIM = 100
DEVICE = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %%
# Dataset Loader
class MovieFramesDataset(Dataset):
    def __init__(self, root_dir, tranform=None):
        self.image_paths = sorted(glob(os.path.join(root_dir, "*.jpeg")))
        self.transform = transform

    def __len__(self):
        return len(self.image_paths)
    
    def __getitem__(self, idx):
        image_path = self.image_paths[idx]
        with open(image_path, 'rb') as f:
            image = Image.open(f).convert('L') # Convert to grayscale
        if self.transform:
            image = self.transform(image)
        return image

transform = transforms.Compose([
    transforms.Resize((IMAGE_SIZE, IMAGE_SIZE)), 
    transforms.ToTensor(),
    transforms.Normalize([0.5], [0.5])
])

# %%
dataset = MovieFramesDataset(DATA_DIR, tranform=transform)
dataloader = DataLoader(dataset, batch_size=BATCH_SIZE, shuffle=True, num_workers=4)

# %%
# Generator
class Generator(nn.Module):
    def __init__(self):
        super(Generator, self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(1, 64, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(64, 128, 4, 2, 1, bias=False),
            nn.BatchNorm2d(128), 
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(128, 256, 4, 2, 1, bias=False),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(256, 1, 4, 1, 0, bias=False),
            nn.Sigmoid()
        )
    
    def forward(self, x):
        return self.model(x).view(-1, 1).squeeze(1)

# Discriminator
class Discriminator(nn.Module):
    def __init__(self):
        super(Discriminator, self).__init__()
        self.model = nn.Sequential(
            nn.Conv2d(1, 64, 4, 2, 1, bias=False),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(64, 128, 4, 2, 1, bias=False),
            nn.BatchNorm2d(128),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(128, 256, 4, 2, 1, bias=False),
            nn.BatchNorm2d(256),
            nn.LeakyReLU(0.2, inplace=True),
            nn.Conv2d(256, 1, 4, 1, 0, bias=False),
            nn.Sigmoid()            
        )
    def forward(self, x):
        return self.model(x).view(-1, 1).squeeze(1)

# %%
# Initialize
netG = Generator().to(DEVICE)
netD = Discriminator().to(DEVICE)
criterion = nn.BCELoss()
optimizerD = optim.Adam(netD.parameters(), lr=0.0002, betas=(0.5, 0.999))
optimizerG = optim.Adam(netG.parameters(), lr=0.0002, betas=(0.5, 0.999))

# Labels
real_label = 1
fake_label = 0

# Training Loop
for epoch in tqdm(range(EPOCHS), desc=f"Training...",  ascii="░▒▓█"):
    for i, data in enumerate(dataloader, 0):
        # Update Discriminator with real data
        netD.zero_grad()
        real_cpu = data.to(DEVICE)
        b_size = real_cpu.size(0)
        label = torch.full((b_size,), real_label, device=DEVICE)
        output = netD(real_cpu)
        errD_real = criterion(output, label)
        errD_real.backward()

        # Generate fake image
        noise = torch.randn(b_size, LATENT_DIM, 1, 1, device=DEVICE)
        fake = netG(noise)
        label.fill_(fake_label)
        output = netD(fake.detach())
        errD_fake = criterion(output, label)
        errD_fake.backward()
        optimizerD.step()

        # Update Generator
        netG.zero_grad()
        label.fill_(real_label) # Generator wants D to believe its output is real
        output = netD(fake)
        errG = criterion(output, label)
        errG.backward()
        optimizerG.step()

        if i % 50 == 0:
            print(f"[{epoch}/{EPOCHS}][{i}/{len(dataloader)}] Loss_D: {errD_real+errD_fake:.4f} Loss_G: {errG:.4f}")
    utils.save_image(fake.detach(), f"output/epoch_{epoch:03}.png",)
# Out:
# Training...:   0%|░░░░░░░░░░| 0/100 [00:23<?, ?it/s]
# Training...:   0%|░░░░░░░░░░| 0/100 [00:23<?, ?it/s]
# Training...:   0%|░░░░░░░░░░| 0/100 [00:23<?, ?it/s]
# Training...:   0%|░░░░░░░░░░| 0/100 [00:23<?, ?it/s]
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 14
#      12 # Training Loop
#      13 for epoch in tqdm(range(EPOCHS), desc=f"Training...",  ascii="░▒▓█"):
# ---> 14     for i, data in enumerate(dataloader, 0):
#      15         # Update Discriminator with real data
#      16         netD.zero_grad()
#      17         real_cpu = data.to(DEVICE)
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/torch/utils/data/dataloader.py:729, in _BaseDataLoaderIter.__next__(self)
#     728 def __next__(self) -> Any:
# --> 729     with torch.autograd.profiler.record_function(self._profile_name):
#     730         if self._sampler_iter is None:
#     731             # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     732             self._reset()  # type: ignore[call-arg]
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/torch/utils/data/dataloader.py:729, in _BaseDataLoaderIter.__next__(self)
#     728 def __next__(self) -> Any:
# --> 729     with torch.autograd.profiler.record_function(self._profile_name):
#     730         if self._sampler_iter is None:
#     731             # TODO(https://github.com/pytorch/pytorch/issues/76750)
#     732             self._reset()  # type: ignore[call-arg]
#
# File _pydevd_bundle\\pydevd_cython.pyx:1697, in _pydevd_bundle.pydevd_cython.SafeCallWrapper.__call__()
#
# File _pydevd_bundle\\pydevd_cython.pyx:634, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:1368, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:1311, in _pydevd_bundle.pydevd_cython.PyDBFrame.trace_dispatch()
#
# File _pydevd_bundle\\pydevd_cython.pyx:494, in _pydevd_bundle.pydevd_cython.PyDBFrame.do_wait_suspend()
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py:2188, in PyDB.do_wait_suspend(self, thread, frame, event, arg, exception_type)
#    2185             from_this_thread.append(frame_custom_thread_id)
#    2187     with self._threads_suspended_single_notification.notify_thread_suspended(thread_id, thread, stop_reason):
# -> 2188         keep_suspended = self._do_wait_suspend(thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2190 frames_list = None
#    2192 if keep_suspended:
#    2193     # This means that we should pause again after a set next statement.
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py:2257, in PyDB._do_wait_suspend(self, thread, frame, event, arg, trace_suspend_type, from_this_thread, frames_tracker)
#    2254                 queue.put(internal_cmd)
#    2255                 wait_timeout = TIMEOUT_FAST
# -> 2257         notify_event.wait(wait_timeout)
#    2258         notify_event.clear()
#    2260 finally:
#
# File ~/anaconda3/envs/torch/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~/anaconda3/envs/torch/lib/python3.10/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 14
#      12 # Training Loop
#      13 for epoch in tqdm(range(EPOCHS), desc=f"Training...",  ascii="░▒▓█"):
# ---> 14     for i, data in enumerate(dataloader, 0):
#      15         # Update Discriminator with real data
#      16         netD.zero_grad()
#      17         real_cpu = data.to(DEVICE)
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/torch/utils/data/dataloader.py:493, in DataLoader.__iter__(self)
#     491     return self._iterator
#     492 else:
# --> 493     return self._get_iterator()
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/torch/utils/data/dataloader.py:424, in DataLoader._get_iterator(self)
#     422 else:
#     423     self.check_worker_number_rationality()
# --> 424     return _MultiProcessingDataLoaderIter(self)
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1171, in _MultiProcessingDataLoaderIter.__init__(self, loader)
#    1164 w.daemon = True
#    1165 # NB: Process.start() actually take some time as it needs to
#    1166 #     start a process and pass the arguments over via a pipe.
#    1167 #     Therefore, we only add a worker to self._workers list after
#    1168 #     it started, so that we do not call .join() if program dies
#    1169 #     before it starts, and __del__ tries to join but will get:
#    1170 #     AssertionError: can only join a started process.
# -> 1171 w.start()
#    1172 self._index_queues.append(index_queue)
#    1173 self._workers.append(w)
#
# File ~/anaconda3/envs/torch/lib/python3.10/multiprocessing/process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File ~/anaconda3/envs/torch/lib/python3.10/multiprocessing/context.py:224, in Process._Popen(process_obj)
#     222 @staticmethod
#     223 def _Popen(process_obj):
# --> 224     return _default_context.get_context().Process._Popen(process_obj)
#
# File ~/anaconda3/envs/torch/lib/python3.10/multiprocessing/context.py:281, in ForkProcess._Popen(process_obj)
#     278 @staticmethod
#     279 def _Popen(process_obj):
#     280     from .popen_fork import Popen
# --> 281     return Popen(process_obj)
#
# File ~/anaconda3/envs/torch/lib/python3.10/multiprocessing/popen_fork.py:19, in Popen.__init__(self, process_obj)
#      17 self.returncode = None
#      18 self.finalizer = None
# ---> 19 self._launch(process_obj)
#
# File ~/anaconda3/envs/torch/lib/python3.10/multiprocessing/popen_fork.py:66, in Popen._launch(self, process_obj)
#      64 parent_r, child_w = os.pipe()
#      65 child_r, parent_w = os.pipe()
# ---> 66 self.pid = os.fork()
#      67 if self.pid == 0:
#      68     try:
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydev_bundle/pydev_monkey.py:965, in create_fork.<locals>.new_fork()
#     963     PydevdCustomization.DEFAULT_PROTOCOL = protocol
#     964     PydevdCustomization.DEBUG_MODE = debug_mode
# --> 965     _on_forked_process(setup_tracing=apply_arg_patch and not is_subprocess_fork)
#     966 else:
#     967     set_global_debugger(None)
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydev_bundle/pydev_monkey.py:240, in _on_forked_process(setup_tracing)
#     237 import pydevd
#     239 pydevd.threadingCurrentThread().__pydevd_main_thread = True
# --> 240 pydevd.settrace_forked(setup_tracing=setup_tracing)
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py:3348, in settrace_forked(setup_tracing)
#    3345 if clear_thread_local_info is not None:
#    3346     clear_thread_local_info()
# -> 3348 settrace(
#    3349     host,
#    3350     port=port,
#    3351     suspend=False,
#    3352     trace_only_current_thread=False,
#    3353     overwrite_prev_trace=True,
#    3354     patch_multiprocessing=True,
#    3355     access_token=access_token,
#    3356     client_access_token=client_access_token,
#    3357 )
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py:3020, in settrace(host, stdout_to_server, stderr_to_server, port, suspend, trace_only_current_thread, overwrite_prev_trace, patch_multiprocessing, stop_at_frame, block_until_connected, wait_for_ready_to_run, dont_trace_start_patterns, dont_trace_end_patterns, access_token, client_access_token, notify_stdin, protocol, **kwargs)
#    3017 __setup_holder__ = kwargs.get("__setup_holder__")
#    3019 with _set_trace_lock:
# -> 3020     _locked_settrace(
#    3021         host,
#    3022         stdout_to_server,
#    3023         stderr_to_server,
#    3024         port,
#    3025         suspend,
#    3026         trace_only_current_thread,
#    3027         patch_multiprocessing,
#    3028         stop_at_frame,
#    3029         block_until_connected,
#    3030         wait_for_ready_to_run,
#    3031         dont_trace_start_patterns,
#    3032         dont_trace_end_patterns,
#    3033         access_token,
#    3034         client_access_token,
#    3035         __setup_holder__=__setup_holder__,
#    3036         notify_stdin=notify_stdin,
#    3037     )
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py:3129, in _locked_settrace(host, stdout_to_server, stderr_to_server, port, suspend, trace_only_current_thread, patch_multiprocessing, stop_at_frame, block_until_connected, wait_for_ready_to_run, dont_trace_start_patterns, dont_trace_end_patterns, access_token, client_access_token, __setup_holder__, notify_stdin)
#    3126 if not wait_for_ready_to_run:
#    3127     py_db.ready_to_run = True
# -> 3129 py_db.wait_for_ready_to_run()
#    3130 py_db.start_auxiliary_daemon_threads()
#    3132 try:
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py:899, in PyDB.wait_for_ready_to_run(self)
#     897 self.process_internal_commands()
#     898 self._py_db_command_thread_event.clear()
# --> 899 self._py_db_command_thread_event.wait(TIMEOUT_FAST)
#
# File ~/anaconda3/envs/torch/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~/anaconda3/envs/torch/lib/python3.10/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 14
#      12 # Training Loop
#      13 for epoch in tqdm(range(EPOCHS), desc=f"Training...",  ascii="░▒▓█"):
# ---> 14     for i, data in enumerate(dataloader, 0):
#      15         # Update Discriminator with real data
#      16         netD.zero_grad()
#      17         real_cpu = data.to(DEVICE)
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/torch/utils/data/dataloader.py:493, in DataLoader.__iter__(self)
#     491     return self._iterator
#     492 else:
# --> 493     return self._get_iterator()
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/torch/utils/data/dataloader.py:424, in DataLoader._get_iterator(self)
#     422 else:
#     423     self.check_worker_number_rationality()
# --> 424     return _MultiProcessingDataLoaderIter(self)
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1171, in _MultiProcessingDataLoaderIter.__init__(self, loader)
#    1164 w.daemon = True
#    1165 # NB: Process.start() actually take some time as it needs to
#    1166 #     start a process and pass the arguments over via a pipe.
#    1167 #     Therefore, we only add a worker to self._workers list after
#    1168 #     it started, so that we do not call .join() if program dies
#    1169 #     before it starts, and __del__ tries to join but will get:
#    1170 #     AssertionError: can only join a started process.
# -> 1171 w.start()
#    1172 self._index_queues.append(index_queue)
#    1173 self._workers.append(w)
#
# File ~/anaconda3/envs/torch/lib/python3.10/multiprocessing/process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File ~/anaconda3/envs/torch/lib/python3.10/multiprocessing/context.py:224, in Process._Popen(process_obj)
#     222 @staticmethod
#     223 def _Popen(process_obj):
# --> 224     return _default_context.get_context().Process._Popen(process_obj)
#
# File ~/anaconda3/envs/torch/lib/python3.10/multiprocessing/context.py:281, in ForkProcess._Popen(process_obj)
#     278 @staticmethod
#     279 def _Popen(process_obj):
#     280     from .popen_fork import Popen
# --> 281     return Popen(process_obj)
#
# File ~/anaconda3/envs/torch/lib/python3.10/multiprocessing/popen_fork.py:19, in Popen.__init__(self, process_obj)
#      17 self.returncode = None
#      18 self.finalizer = None
# ---> 19 self._launch(process_obj)
#
# File ~/anaconda3/envs/torch/lib/python3.10/multiprocessing/popen_fork.py:66, in Popen._launch(self, process_obj)
#      64 parent_r, child_w = os.pipe()
#      65 child_r, parent_w = os.pipe()
# ---> 66 self.pid = os.fork()
#      67 if self.pid == 0:
#      68     try:
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydev_bundle/pydev_monkey.py:965, in create_fork.<locals>.new_fork()
#     963     PydevdCustomization.DEFAULT_PROTOCOL = protocol
#     964     PydevdCustomization.DEBUG_MODE = debug_mode
# --> 965     _on_forked_process(setup_tracing=apply_arg_patch and not is_subprocess_fork)
#     966 else:
#     967     set_global_debugger(None)
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydev_bundle/pydev_monkey.py:240, in _on_forked_process(setup_tracing)
#     237 import pydevd
#     239 pydevd.threadingCurrentThread().__pydevd_main_thread = True
# --> 240 pydevd.settrace_forked(setup_tracing=setup_tracing)
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py:3348, in settrace_forked(setup_tracing)
#    3345 if clear_thread_local_info is not None:
#    3346     clear_thread_local_info()
# -> 3348 settrace(
#    3349     host,
#    3350     port=port,
#    3351     suspend=False,
#    3352     trace_only_current_thread=False,
#    3353     overwrite_prev_trace=True,
#    3354     patch_multiprocessing=True,
#    3355     access_token=access_token,
#    3356     client_access_token=client_access_token,
#    3357 )
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py:3020, in settrace(host, stdout_to_server, stderr_to_server, port, suspend, trace_only_current_thread, overwrite_prev_trace, patch_multiprocessing, stop_at_frame, block_until_connected, wait_for_ready_to_run, dont_trace_start_patterns, dont_trace_end_patterns, access_token, client_access_token, notify_stdin, protocol, **kwargs)
#    3017 __setup_holder__ = kwargs.get("__setup_holder__")
#    3019 with _set_trace_lock:
# -> 3020     _locked_settrace(
#    3021         host,
#    3022         stdout_to_server,
#    3023         stderr_to_server,
#    3024         port,
#    3025         suspend,
#    3026         trace_only_current_thread,
#    3027         patch_multiprocessing,
#    3028         stop_at_frame,
#    3029         block_until_connected,
#    3030         wait_for_ready_to_run,
#    3031         dont_trace_start_patterns,
#    3032         dont_trace_end_patterns,
#    3033         access_token,
#    3034         client_access_token,
#    3035         __setup_holder__=__setup_holder__,
#    3036         notify_stdin=notify_stdin,
#    3037     )
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py:3129, in _locked_settrace(host, stdout_to_server, stderr_to_server, port, suspend, trace_only_current_thread, patch_multiprocessing, stop_at_frame, block_until_connected, wait_for_ready_to_run, dont_trace_start_patterns, dont_trace_end_patterns, access_token, client_access_token, __setup_holder__, notify_stdin)
#    3126 if not wait_for_ready_to_run:
#    3127     py_db.ready_to_run = True
# -> 3129 py_db.wait_for_ready_to_run()
#    3130 py_db.start_auxiliary_daemon_threads()
#    3132 try:
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py:899, in PyDB.wait_for_ready_to_run(self)
#     897 self.process_internal_commands()
#     898 self._py_db_command_thread_event.clear()
# --> 899 self._py_db_command_thread_event.wait(TIMEOUT_FAST)
#
# File ~/anaconda3/envs/torch/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~/anaconda3/envs/torch/lib/python3.10/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 14
#      12 # Training Loop
#      13 for epoch in tqdm(range(EPOCHS), desc=f"Training...",  ascii="░▒▓█"):
# ---> 14     for i, data in enumerate(dataloader, 0):
#      15         # Update Discriminator with real data
#      16         netD.zero_grad()
#      17         real_cpu = data.to(DEVICE)
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/torch/utils/data/dataloader.py:493, in DataLoader.__iter__(self)
#     491     return self._iterator
#     492 else:
# --> 493     return self._get_iterator()
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/torch/utils/data/dataloader.py:424, in DataLoader._get_iterator(self)
#     422 else:
#     423     self.check_worker_number_rationality()
# --> 424     return _MultiProcessingDataLoaderIter(self)
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1171, in _MultiProcessingDataLoaderIter.__init__(self, loader)
#    1164 w.daemon = True
#    1165 # NB: Process.start() actually take some time as it needs to
#    1166 #     start a process and pass the arguments over via a pipe.
#    1167 #     Therefore, we only add a worker to self._workers list after
#    1168 #     it started, so that we do not call .join() if program dies
#    1169 #     before it starts, and __del__ tries to join but will get:
#    1170 #     AssertionError: can only join a started process.
# -> 1171 w.start()
#    1172 self._index_queues.append(index_queue)
#    1173 self._workers.append(w)
#
# File ~/anaconda3/envs/torch/lib/python3.10/multiprocessing/process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File ~/anaconda3/envs/torch/lib/python3.10/multiprocessing/context.py:224, in Process._Popen(process_obj)
#     222 @staticmethod
#     223 def _Popen(process_obj):
# --> 224     return _default_context.get_context().Process._Popen(process_obj)
#
# File ~/anaconda3/envs/torch/lib/python3.10/multiprocessing/context.py:281, in ForkProcess._Popen(process_obj)
#     278 @staticmethod
#     279 def _Popen(process_obj):
#     280     from .popen_fork import Popen
# --> 281     return Popen(process_obj)
#
# File ~/anaconda3/envs/torch/lib/python3.10/multiprocessing/popen_fork.py:19, in Popen.__init__(self, process_obj)
#      17 self.returncode = None
#      18 self.finalizer = None
# ---> 19 self._launch(process_obj)
#
# File ~/anaconda3/envs/torch/lib/python3.10/multiprocessing/popen_fork.py:66, in Popen._launch(self, process_obj)
#      64 parent_r, child_w = os.pipe()
#      65 child_r, parent_w = os.pipe()
# ---> 66 self.pid = os.fork()
#      67 if self.pid == 0:
#      68     try:
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydev_bundle/pydev_monkey.py:965, in create_fork.<locals>.new_fork()
#     963     PydevdCustomization.DEFAULT_PROTOCOL = protocol
#     964     PydevdCustomization.DEBUG_MODE = debug_mode
# --> 965     _on_forked_process(setup_tracing=apply_arg_patch and not is_subprocess_fork)
#     966 else:
#     967     set_global_debugger(None)
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydev_bundle/pydev_monkey.py:240, in _on_forked_process(setup_tracing)
#     237 import pydevd
#     239 pydevd.threadingCurrentThread().__pydevd_main_thread = True
# --> 240 pydevd.settrace_forked(setup_tracing=setup_tracing)
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py:3348, in settrace_forked(setup_tracing)
#    3345 if clear_thread_local_info is not None:
#    3346     clear_thread_local_info()
# -> 3348 settrace(
#    3349     host,
#    3350     port=port,
#    3351     suspend=False,
#    3352     trace_only_current_thread=False,
#    3353     overwrite_prev_trace=True,
#    3354     patch_multiprocessing=True,
#    3355     access_token=access_token,
#    3356     client_access_token=client_access_token,
#    3357 )
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py:3020, in settrace(host, stdout_to_server, stderr_to_server, port, suspend, trace_only_current_thread, overwrite_prev_trace, patch_multiprocessing, stop_at_frame, block_until_connected, wait_for_ready_to_run, dont_trace_start_patterns, dont_trace_end_patterns, access_token, client_access_token, notify_stdin, protocol, **kwargs)
#    3017 __setup_holder__ = kwargs.get("__setup_holder__")
#    3019 with _set_trace_lock:
# -> 3020     _locked_settrace(
#    3021         host,
#    3022         stdout_to_server,
#    3023         stderr_to_server,
#    3024         port,
#    3025         suspend,
#    3026         trace_only_current_thread,
#    3027         patch_multiprocessing,
#    3028         stop_at_frame,
#    3029         block_until_connected,
#    3030         wait_for_ready_to_run,
#    3031         dont_trace_start_patterns,
#    3032         dont_trace_end_patterns,
#    3033         access_token,
#    3034         client_access_token,
#    3035         __setup_holder__=__setup_holder__,
#    3036         notify_stdin=notify_stdin,
#    3037     )
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py:3129, in _locked_settrace(host, stdout_to_server, stderr_to_server, port, suspend, trace_only_current_thread, patch_multiprocessing, stop_at_frame, block_until_connected, wait_for_ready_to_run, dont_trace_start_patterns, dont_trace_end_patterns, access_token, client_access_token, __setup_holder__, notify_stdin)
#    3126 if not wait_for_ready_to_run:
#    3127     py_db.ready_to_run = True
# -> 3129 py_db.wait_for_ready_to_run()
#    3130 py_db.start_auxiliary_daemon_threads()
#    3132 try:
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py:899, in PyDB.wait_for_ready_to_run(self)
#     897 self.process_internal_commands()
#     898 self._py_db_command_thread_event.clear()
# --> 899 self._py_db_command_thread_event.wait(TIMEOUT_FAST)
#
# File ~/anaconda3/envs/torch/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~/anaconda3/envs/torch/lib/python3.10/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[7], line 14
#      12 # Training Loop
#      13 for epoch in tqdm(range(EPOCHS), desc=f"Training...",  ascii="░▒▓█"):
# ---> 14     for i, data in enumerate(dataloader, 0):
#      15         # Update Discriminator with real data
#      16         netD.zero_grad()
#      17         real_cpu = data.to(DEVICE)
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/torch/utils/data/dataloader.py:493, in DataLoader.__iter__(self)
#     491     return self._iterator
#     492 else:
# --> 493     return self._get_iterator()
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/torch/utils/data/dataloader.py:424, in DataLoader._get_iterator(self)
#     422 else:
#     423     self.check_worker_number_rationality()
# --> 424     return _MultiProcessingDataLoaderIter(self)
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/torch/utils/data/dataloader.py:1171, in _MultiProcessingDataLoaderIter.__init__(self, loader)
#    1164 w.daemon = True
#    1165 # NB: Process.start() actually take some time as it needs to
#    1166 #     start a process and pass the arguments over via a pipe.
#    1167 #     Therefore, we only add a worker to self._workers list after
#    1168 #     it started, so that we do not call .join() if program dies
#    1169 #     before it starts, and __del__ tries to join but will get:
#    1170 #     AssertionError: can only join a started process.
# -> 1171 w.start()
#    1172 self._index_queues.append(index_queue)
#    1173 self._workers.append(w)
#
# File ~/anaconda3/envs/torch/lib/python3.10/multiprocessing/process.py:121, in BaseProcess.start(self)
#     118 assert not _current_process._config.get('daemon'), \
#     119        'daemonic processes are not allowed to have children'
#     120 _cleanup()
# --> 121 self._popen = self._Popen(self)
#     122 self._sentinel = self._popen.sentinel
#     123 # Avoid a refcycle if the target function holds an indirect
#     124 # reference to the process object (see bpo-30775)
#
# File ~/anaconda3/envs/torch/lib/python3.10/multiprocessing/context.py:224, in Process._Popen(process_obj)
#     222 @staticmethod
#     223 def _Popen(process_obj):
# --> 224     return _default_context.get_context().Process._Popen(process_obj)
#
# File ~/anaconda3/envs/torch/lib/python3.10/multiprocessing/context.py:281, in ForkProcess._Popen(process_obj)
#     278 @staticmethod
#     279 def _Popen(process_obj):
#     280     from .popen_fork import Popen
# --> 281     return Popen(process_obj)
#
# File ~/anaconda3/envs/torch/lib/python3.10/multiprocessing/popen_fork.py:19, in Popen.__init__(self, process_obj)
#      17 self.returncode = None
#      18 self.finalizer = None
# ---> 19 self._launch(process_obj)
#
# File ~/anaconda3/envs/torch/lib/python3.10/multiprocessing/popen_fork.py:66, in Popen._launch(self, process_obj)
#      64 parent_r, child_w = os.pipe()
#      65 child_r, parent_w = os.pipe()
# ---> 66 self.pid = os.fork()
#      67 if self.pid == 0:
#      68     try:
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydev_bundle/pydev_monkey.py:965, in create_fork.<locals>.new_fork()
#     963     PydevdCustomization.DEFAULT_PROTOCOL = protocol
#     964     PydevdCustomization.DEBUG_MODE = debug_mode
# --> 965     _on_forked_process(setup_tracing=apply_arg_patch and not is_subprocess_fork)
#     966 else:
#     967     set_global_debugger(None)
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/debugpy/_vendored/pydevd/_pydev_bundle/pydev_monkey.py:240, in _on_forked_process(setup_tracing)
#     237 import pydevd
#     239 pydevd.threadingCurrentThread().__pydevd_main_thread = True
# --> 240 pydevd.settrace_forked(setup_tracing=setup_tracing)
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py:3348, in settrace_forked(setup_tracing)
#    3345 if clear_thread_local_info is not None:
#    3346     clear_thread_local_info()
# -> 3348 settrace(
#    3349     host,
#    3350     port=port,
#    3351     suspend=False,
#    3352     trace_only_current_thread=False,
#    3353     overwrite_prev_trace=True,
#    3354     patch_multiprocessing=True,
#    3355     access_token=access_token,
#    3356     client_access_token=client_access_token,
#    3357 )
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py:3020, in settrace(host, stdout_to_server, stderr_to_server, port, suspend, trace_only_current_thread, overwrite_prev_trace, patch_multiprocessing, stop_at_frame, block_until_connected, wait_for_ready_to_run, dont_trace_start_patterns, dont_trace_end_patterns, access_token, client_access_token, notify_stdin, protocol, **kwargs)
#    3017 __setup_holder__ = kwargs.get("__setup_holder__")
#    3019 with _set_trace_lock:
# -> 3020     _locked_settrace(
#    3021         host,
#    3022         stdout_to_server,
#    3023         stderr_to_server,
#    3024         port,
#    3025         suspend,
#    3026         trace_only_current_thread,
#    3027         patch_multiprocessing,
#    3028         stop_at_frame,
#    3029         block_until_connected,
#    3030         wait_for_ready_to_run,
#    3031         dont_trace_start_patterns,
#    3032         dont_trace_end_patterns,
#    3033         access_token,
#    3034         client_access_token,
#    3035         __setup_holder__=__setup_holder__,
#    3036         notify_stdin=notify_stdin,
#    3037     )
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py:3129, in _locked_settrace(host, stdout_to_server, stderr_to_server, port, suspend, trace_only_current_thread, patch_multiprocessing, stop_at_frame, block_until_connected, wait_for_ready_to_run, dont_trace_start_patterns, dont_trace_end_patterns, access_token, client_access_token, __setup_holder__, notify_stdin)
#    3126 if not wait_for_ready_to_run:
#    3127     py_db.ready_to_run = True
# -> 3129 py_db.wait_for_ready_to_run()
#    3130 py_db.start_auxiliary_daemon_threads()
#    3132 try:
#
# File ~/anaconda3/envs/torch/lib/python3.10/site-packages/debugpy/_vendored/pydevd/pydevd.py:899, in PyDB.wait_for_ready_to_run(self)
#     897 self.process_internal_commands()
#     898 self._py_db_command_thread_event.clear()
# --> 899 self._py_db_command_thread_event.wait(TIMEOUT_FAST)
#
# File ~/anaconda3/envs/torch/lib/python3.10/threading.py:607, in Event.wait(self, timeout)
#     605 signaled = self._flag
#     606 if not signaled:
# --> 607     signaled = self._cond.wait(timeout)
#     608 return signaled
#
# File ~/anaconda3/envs/torch/lib/python3.10/threading.py:324, in Condition.wait(self, timeout)
#     322 else:
#     323     if timeout > 0:
# --> 324         gotit = waiter.acquire(True, timeout)
#     325     else:
#     326         gotit = waiter.acquire(False)
#
# KeyboardInterrupt:
